# %% [markdown]
# # Đáp án Bài tập Thực hành Tuần 01: Giới thiệu học phần & ADT
# *(Dành cho Giảng viên/Trợ giảng đối chiếu)*

# %% [markdown]
# ### Bài 1: Đáp án

# %%
# Lời giải chi tiết mẫu
