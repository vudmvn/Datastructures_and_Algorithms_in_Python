# %% [markdown]
# # Đáp án Bài tập Thực hành Tuần 02: Độ phức tạp tiệm cận & Big-O
# *(Dành cho Giảng viên/Trợ giảng đối chiếu)*

# %% [markdown]
# ### Bài 1: Đáp án

# %%
# Lời giải chi tiết mẫu
